# %% [markdown]
# # Data structure—the user will define the value more then one
# - list
# - tuple
# - set
# - dict
# - these are inbuilt data structures.

# %%
l = [] # list
l
# Out:
# []

# %%
len(l)
# Out:
# 0

# %%
l.append(10)
l
# Out:
# [10]

# %%
len(l)
# Out:
# 1

# %%
l.append(10)
l.append(20)
l.append(30)
l.append(40)
l.append(40)
l
# Out:
# [10, 20, 30, 40, 40]

# %%
len(l)
# Out:
# 5

# %%
id(l)
# Out:
# 3192838601536

# %%
type(l)
# Out:
# list

# %%
l[:]  #slice
# Out:
# [10, 20, 30, 40, 40]

# %%
l[1]
# Out:
# 20

# %%
l[0]
# Out:
# 10

# %%
l[-3]
# Out:
# 30

# %%
l
# Out:
# [10, 20, 30, 40, 40]

# %%
l1=l.copy()
l1
# Out:
# [10, 20, 30, 40, 40]

# %%
l == l1
# Out:
# True

# %%
l1.append(3)

# %%
l
# Out:
# [10, 20, 30, 40, 40, 3]

# %%
l == l1
# Out:
# True

# %%
l1
# Out:
# [10, 20, 30, 40, 40, 3]

# %%
l.remove(3)

# %%
l
# Out:
# [10, 20, 30, 40, 40]

# %%
l1
# Out:
# [10, 20, 30, 40, 40]

# %%
l == l1
# Out:
# True

# %%
l1.append(2)

# %%
l1
# Out:
# [10, 20, 30, 40, 40, 2]

# %%
l
# Out:
# [10, 20, 30, 40, 40, 2]

# %%
l == l1
# Out:
# True

# %%
l1 == l
# Out:
# True

# %%
l1.append(2.3)
l1.append(True)
l1.append(1+2j)
l1
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, True, (1+2j)]

# %%
l1.append(50)
l1
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50]

# %%
l1.count(10)
# Out:
# 1

# %%
l.count(40)
# Out:
# 2

# %%
l.count(100)
# Out:
# 0

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[53], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l2 = l1.copy()

# %%
l2
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50]

# %%
l2.remove(True)

# %%
l2
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, (1+2j), 50]

# %%
l1
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50]

# %%
l2.remove(1+2j)
l2
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, 50]

# %%
l2.clear()

# %%
l2
# Out:
# []

# %%
l1
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50]

# %%
l
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50]

# %%
del l2

# %%
l2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[65], line 1
# ----> 1 l2
#
# NameError: name 'l2' is not defined

# %%
l
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50]

# %%
l1
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50]

# %%
print(l)
print(l1)
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50]
# [10, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50]

# %%
print(len(l))
# Out:
# 10

# %%
print(len(l1))
# Out:
# 10

# %%
for i in l:
    print(i)
# Out:
# 10
# 20
# 30
# 40
# 40
# 2
# 2.3
# True
# (1+2j)
# 50

# %%
l.append([1,2,3,'hi'])

# %%
l
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50, [1, 2, 3, 'hi']]

# %%
l1
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50, [1, 2, 3, 'hi']]

# %%
l2 = l.copy()

# %%
l2
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50, [1, 2, 3, 'hi']]

# %%
l2.remove(40)

# %%
l2
# Out:
# [10, 20, 30, 40, 2, 2.3, True, (1+2j), 50, [1, 2, 3, 'hi']]

# %%
l1
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50, [1, 2, 3, 'hi']]

# %%
l
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50, [1, 2, 3, 'hi']]

# %%
l[10]
# Out:
# [1, 2, 3, 'hi']

# %% [markdown]
# # remove() vs pop()

# %%
l2
# Out:
# [10, 20, 30, 40, 2, 2.3, True, (1+2j), 50, [1, 2, 3, 'hi']]

# %%
l2.pop()
# Out:
# [1, 2, 3, 'hi']

# %%
l2.pop()
# Out:
# 50

# %%
l2
# Out:
# [10, 20, 30, 40, 2, 2.3, True, (1+2j)]

# %%
l2.pop(5)
# Out:
# 2.3

# %%
l2
# Out:
# [10, 20, 30, 40, 2, True, (1+2j)]

# %%
l2.insert(3,50)

# %%
l2
# Out:
# [10, 20, 30, 50, 40, 2, True, (1+2j)]

# %%
l1
# Out:
# [10, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50, [1, 2, 3, 'hi']]

# %%
l1.insert(1,2)

# %%
l1
# Out:
# [10, 2, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50, [1, 2, 3, 'hi']]

# %%
l1.insert(111,2)

# %%
l1
# Out:
# [10, 2, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50, [1, 2, 3, 'hi'], 2]

# %%
l
# Out:
# [10, 2, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50, [1, 2, 3, 'hi'], 2]

# %%
l.pop()
# Out:
# 2

# %%
l
# Out:
# [10, 2, 20, 30, 40, 40]

# %%
l.pop()
# Out:
# [1, 2, 3, 'hi']

# %%
l
# Out:
# [10, 2, 20, 30, 40, 40, 2, 2.3, True, (1+2j), 50]

# %%
l.pop()
# Out:
# 50

# %%
l.pop()
# Out:
# (1+2j)

# %%
l.pop()
# Out:
# True

# %%
l.pop()
# Out:
# 2.3

# %%
l.pop()
# Out:
# 2

# %%
l
# Out:
# [10, 2, 20, 30, 40, 40]

# %%
l.pop()
# Out:
# 40

# %%
l
# Out:
# [10, 2, 20, 30, 40]

# %%
l.extend(l2)

# %%
l
# Out:
# [10, 2, 20, 30, 40, 10, 20, 30, 50, 40, 2, True, (1+2j), 10, 2, 20, 30, 40]

# %%
l.index(True)
# Out:
# 11

# %%
l
# Out:
# [10, 2, 20, 30, 40, 10, 20, 30, 50, 40, 2, True, (1+2j), 10, 2, 20, 30, 40]

# %%
l.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[131], line 1
# ----> 1 l.sort()
#
# TypeError: '<' not supported between instances of 'complex' and 'int'

# %%
l1
# Out:
# [True, 2, 2, 10, 10, 20, 20, 30, 30, 40, 40, 50, (1+2j), 10, 2, 20, 30, 40]

# %%
l2
# Out:
# [10, 20, 30, 50, 40, 2, True, (1+2j), 10, 2, 20, 30, 40]

# %%
l2.remove(True)

# %%
l2.remove(1+2j)

# %%
l2
# Out:
# [10, 20, 30, 50, 40, 2, 10, 2, 20, 30, 40]

# %%
l2.sort()

# %%
l2
# Out:
# [2, 2, 10, 20, 20, 30, 30, 40, 40, 50]

# %%
l2.pop(1)
# Out:
# 2

# %%
l2.sort(reverse=True)

# %%
l2
# Out:
# [50, 40, 40, 30, 30, 20, 20, 10, 2]

# %%
l2[::-2]
# Out:
# [2, 20, 30, 40, 50]

# %%
import keyword
keyword.kwlist
# Out:
# ['False',
#  'None',
#  'True',
#  'and',
#  'as',
#  'assert',
#  'async',
#  'await',
#  'break',
#  'class',
#  'continue',
#  'def',
#  'del',
#  'elif',
#  'else',
#  'except',
#  'finally',
#  'for',
#  'from',
#  'global',
#  'if',
#  'import',
#  'in',
#  'is',
#  'lambda',
#  'nonlocal',
#  'not',
#  'or',
#  'pass',
#  'raise',
#  'return',
#  'try',
#  'while',
#  'with',
#  'yield']

# %%
len(keyword.kwlist)
# Out:
# 35
